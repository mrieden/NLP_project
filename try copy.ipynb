# %%
import os
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Embedding, LSTM, Dense, Bidirectional, Dropout, GRU
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping,ReduceLROnPlateau
import nltk
import re
import unicodedata
from nltk.tokenize import word_tokenize
import pyarabic.araby as araby
from collections import Counter

import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# %%
input_file = 'data.txt'
# input_file = 'cleaned_data.txt'

with open(input_file, 'r', encoding='utf-8') as infile:
    data = infile.read()

# %%
corpus = data.split('\n')
print(corpus[:5])  # Print first 5 lines of the corpus to check the data
# Out:
# ['في البلد', ', اهل البلد متجمعين ومستنين الامل الجديد اللي هيخلصهم من الكابوس اللي عايشين فيه', ', مدير الشرطه: المفروض انه علي وصول', ', واحد من كبار البلد(عم محمود): بس واحد هيعمل ايه يعني؟ المفروض كانوا بعتوا فريق ولا كتيبه لكن واحد؟', ', مدير الشرطه: اللي اعرفه عن اللي باعتينه ان هو بيمثل كتيبه كامله لوحده وهو من اكفأ الظباط هو لوحده كفايه']

# %% [markdown]
# # Clean Text

# %%
def clean_text(text):
    # Remove emojis
    text = re.sub(r'[^\u0600-\u06FF\u0750-\u077F\u08A0-\u08FF]+', ' ', text) 
    text = re.sub(r'\s+', ' ', text).strip() # Remove extra spaces
    text = re.sub(' +', ' ', text)

    
    return text

# %%
def tokenize_arabic(text):
    # Tokenize using NLTK's Arabic-aware tokenizer
    text = clean_text(text)
    
    tokens = word_tokenize(text)
    
    # Remove stopwords (optional)
    from nltk.corpus import stopwords
    arabic_stopwords = set(stopwords.words('arabic'))
    tokens = [token for token in tokens if token not in arabic_stopwords]
    
    return tokens

# %%
# corpus = [clean_text(text) for text in corpus]
corpus = corpus[:7000]# Limit to 5000 samples for demonstration
# Step 2: Tokenize the Text
tokenizer = Tokenizer() #oov_token='<oov>
tokenizer.fit_on_texts([tokenize_arabic(text) for text in corpus])
vocab_size = len(tokenizer.word_index) + 1  # Add 1 for padding token

tokenizer.word_counts
# Out:
# OrderedDict([('البلد', 70),
#              ('اهل', 10),
#              ('متجمعين', 3),
#              ('ومستنين', 2),
#              ('الامل', 6),
#              ('الجديد', 4),
#              ('اللي', 670),
#              ('هيخلصهم', 1),
#              ('الكابوس', 8),
#              ('عايشين', 4),
#              ('مدير', 18),
#              ('الشرطه', 17),
#              ('المفروض', 30),
#              ('انه', 225),
#              ('علي', 586),
#              ('وصول', 2),
#              ('كبار', 2),
#              ('عم', 375),
#              ('محمود', 393),
#              ('هيعمل', 7),
#              ('ايه', 471),
#              ('يعني؟', 17),
#              ('كانوا', 12),
#              ('بعتوا', 1),
#              ('فريق', 3),
#              ('كتيبه', 2),
#              ('واحد؟', 2),
#              ('اعرفه', 7),
#              ('باعتينه', 1),
#              ('ان', 316),
#              ('بيمثل', 1),
#              ('كامله', 3),
#              ('لوحده', 23),
#              ('اكفأ', 4),
#              ('الظباط', 1),
#              ('كفايه', 58),
#              ('عمده', 2),
#              ('يارب', 12),
#              ('يوصل', 8),
#              ('ويخلصنا', 1),
#              ('المصيبة', 1),
#              ('دي', 253),
#              ('هيوصل', 3),
#              ('شاء', 12),
#              ('الله', 4),
#              ('ساحه', 1),
#              ('كبيره', 9),
#              ('مستنين', 4),
#              ('وصوله', 1),
#              ('وفجأة', 1),
#              ('ظهرت', 3),
#              ('عربيه', 10),
#              ('بعيد', 78),
#              ('بتقرب', 3),
#              ('عليهم', 20),
#              ('اهو', 20),
#              ('وصل', 25),
#              ('اهوه', 34),
#              ('معاده', 3),
#              ('بالتمام', 1),
#              ('قربت', 19),
#              ('العربيه', 32),
#              ('ووقفت', 8),
#              ('واتفتح', 1),
#              ('بابها', 2),
#              ('ونزل', 12),
#              ('صحابها', 1),
#              ('طويل', 15),
#              ('عريض', 2),
#              ('قوي', 89),
#              ('ظابط', 15),
#              ('بكل', 17),
#              ('معني', 7),
#              ('الكلمه', 6),
#              ('الكل', 79),
#              ('اتصدم', 11),
#              ('اول', 92),
#              ('شافوه', 3),
#              ('وتنحوا', 1),
#              ('اعوذ', 2),
#              ('بالله', 1),
#              ('الشيطان', 1),
#              ('الرجيم', 1),
#              ('سلام', 20),
#              ('قولا', 1),
#              ('رب', 2),
#              ('رحيم', 1),
#              ('فاتح', 3),
#              ('بوقه', 1),
#              ('ومنطقش', 1),
#              ('وبعد', 23),
#              ('لحظات', 5),
#              ('الصمت', 7),
#              ('والخوف', 1),
#              ('والرهبه', 1),
#              ('الزائر', 2),
#              ('نطق', 1),
#              ('انا', 834),
#              ('المقدم', 13),
#              ('ادهم', 2104),
#              ('صبري', 97),
#              ('عبد', 5),
#              ('السلام', 5),
#              ('حض', 1),
#              ('رتك', 1),
#              ('مكنش', 34),
#              ('عارف', 158),
#              ('يتكلم', 27),
#              ('وبيتهته', 1),
#              ('اهلا', 28),
#              ('بحضرتك', 3),
#              ('لمدير', 1),
#              ('مشيه', 1),
#              ('وكلمهم', 1),
#              ('يبعتوا', 1),
#              ('غيره', 14),
#              ('الشرطة', 1),
#              ('احنا', 83),
#              ('بنقي', 1),
#              ('وبعدين', 97),
#              ('ده', 505),
#              ('ايه؟', 343),
#              ('دول', 21),
#              ('عايزين', 6),
#              ('يخلصوا', 3),
#              ('شكله', 20),
#              ('فبعتوه', 1),
#              ('انت', 591),
#              ('مش', 1046),
#              ('شايف', 3),
#              ('طبعا', 74),
#              ('الحوار', 5),
#              ('بصوت', 10),
#              ('واطي', 1),
#              ('كله', 57),
#              ('سامعه', 5),
#              ('وساكت', 4),
#              ('ومش', 99),
#              ('فارق', 4),
#              ('معاه', 60),
#              ('او', 207),
#              ('يمكن', 38),
#              ('يكون', 60),
#              ('اتعود', 4),
#              ('رفض', 19),
#              ('الناس', 40),
#              ('لشكله', 2),
#              ('بطل', 11),
#              ('يحس', 10),
#              ('باي', 15),
#              ('الم', 2),
#              ('اي', 187),
#              ('نوع', 2),
#              ('ومفيش', 5),
#              ('شيئ', 72),
#              ('بيوجعه', 2),
#              ('كلام', 26),
#              ('نظراتهم', 1),
#              ('المشوه٣', 1),
#              ('نقطة', 232),
#              ('مشوه', 23),
#              ('جدا', 88),
#              ('بهدوء', 3),
#              ('حضراتكم', 3),
#              ('خلصتوا', 1),
#              ('كلامكم', 1),
#              ('ممكن', 132),
#              ('نتكلم', 6),
#              ('المهم', 70),
#              ('مستغنين', 3),
#              ('خدماتي', 1),
#              ('عادي', 25),
#              ('همشي', 9),
#              ('وهتبقوا', 1),
#              ('ريحتوني؟', 1),
#              ('مصدقنا', 1),
#              ('انهم', 19),
#              ('اخيرا', 55),
#              ('عبرونا', 2),
#              ('وبعتولنا', 1),
#              ('حد', 185),
#              ('والله', 1),
#              ('مكنوش', 1),
#              ('هيبقي', 22),
#              ('احسن', 14),
#              ('شكلي', 5),
#              ('عاجبك؟', 1),
#              ('معلش', 16),
#              ('استحمله', 3),
#              ('واهي', 8),
#              ('فتره', 20),
#              ('وهتعدي', 2),
#              ('واوعدك', 7),
#              ('اخلص', 6),
#              ('مهمتي', 3),
#              ('هتشوفه', 1),
#              ('تاني', 182),
#              ('دور', 9),
#              ('وشه', 31),
#              ('وكل', 49),
#              ('ملامحه', 5),
#              ('قرف', 1),
#              ('شكل', 7),
#              ('الظابط', 9),
#              ('صوت', 19),
#              ('اتكلم', 17),
#              ('بابا', 53),
#              ('اتفضلو', 5),
#              ('الشاي', 5),
#              ('وحطت', 10),
#              ('صينيه', 1),
#              ('التربيزه', 3),
#              ('النص', 5),
#              ('وهنا', 17),
#              ('شافت', 7),
#              ('بيك', 14),
#              ('بلدنا', 4),
#              ('تعجبك', 1),
#              ('ويارب', 1),
#              ('تقدر', 18),
#              ('تخلصنا', 1),
#              ('باستغراب', 12),
#              ('انها', 101),
#              ('بتكلمه', 3),
#              ('شاءالله', 1),
#              ('البنت', 13),
#              ('اسمي', 8),
#              ('ليلي', 1683),
#              ('مدرسه', 5),
#              ('وحضرتك', 3),
#              ('مقدم', 4),
#              ('ابوها', 84),
#              ('يالا', 55),
#              ('شوفي', 5),
#              ('وراكي', 2),
#              ('اذنكم', 15),
#              ('الصبح', 32),
#              ('هبعتلك', 2),
#              ('يجيبك', 1),
#              ('القسم', 3),
#              ('عندنا', 8),
#              ('وهوريك', 1),
#              ('ملف', 3),
#              ('القضيه', 6),
#              ('كامل', 6),
#              ('اما', 20),
#              ('دلوقتي', 92),
#              ('فاكيد', 3),
#              ('حضرتك', 54),
#              ('تعبان', 16),
#              ('الطريق', 21),
#              ('ومحتاج', 1),
#              ('للراحه', 1),
#              ('كنا', 10),
#              ('جهزنا', 1),
#              ('لحضرتك', 8),
#              ('مكان', 30),
#              ('عند٣', 1),
#              ('قاطعه', 11),
#              ('العمده', 9),
#              ('لانه', 67),
#              ('معندوش', 5),
#              ('استعداد', 10),
#              ('حاليا', 33),
#              ('يستقبل', 1),
#              ('مسخ', 12),
#              ('بيته', 24),
#              ('لسه', 67),
#              ('بندور', 2),
#              ('مناسب', 3),
#              ('ابتسم', 20),
#              ('فاهم', 29),
#              ('حواليه', 18),
#              ('متشغلوش', 1),
#              ('بالكم', 2),
#              ('بمكان', 1),
#              ('اقامتي', 1),
#              ('كلها', 69),
#              ('ساعه', 27),
#              ('بالكتير', 3),
#              ('ومكاني', 1),
#              ('المدير', 21),
#              ('يعني', 114),
#              ('يوصل؟', 1),
#              ('هقعد', 3),
#              ('كرفان', 1),
#              ('مقطوره', 1),
#              ('مجهزه', 2),
#              ('للعيشه', 1),
#              ('وزمانها', 1),
#              ('سياده', 9),
#              ('بسش', 2),
#              ('هكون', 8),
#              ('مرتاح', 1),
#              ('هتمشي', 7),
#              ('شويه', 105),
#              ('خلي', 15),
#              ('بالك', 42),
#              ('عيال', 14),
#              ('صغيره', 25),
#              ('الشوارع', 1),
#              ('صغيره؟', 1),
#              ('هيخافو', 1),
#              ('منك', 71),
#              ('بمرار', 2),
#              ('وسط', 14),
#              ('عايز', 204),
#              ('اشوف', 14),
#              ('حدودها', 1),
#              ('متخفش', 1),
#              ('العيال', 30),
#              ('الصغيره', 9),
#              ('سابهم', 19),
#              ('وانسحب', 1),
#              ('واول', 47),
#              ('أصواتهم', 1),
#              ('عليت', 1),
#              ('استحاله', 10),
#              ('ازاي', 58),
#              ('هنستحمله', 1),
#              ('وحضرته', 1),
#              ('عايزني', 19),
#              ('استقبله', 1),
#              ('بيتي؟', 1),
#              ('شيطان', 6),
#              ('استقبل', 1),
#              ('انا؟', 14),
#              ('الراجل', 13),
#              ('لازم', 82),
#              ('يمشي', 26),
#              ('همشيه', 1),
#              ('حالا', 13),
#              ('هاتولي', 1),
#              ('بديل', 1),
#              ('ليه', 165),
#              ('معروف', 1),
#              ('عنه', 49),
#              ('عمره', 40),
#              ('فشل', 1),
#              ('مهمه', 17),
#              ('ويفشل', 1),
#              ('ازاي؟', 37),
#              ('يطل', 1),
#              ('بوشه', 1),
#              ('واللي', 13),
#              ('قدامه', 27),
#              ('هيفتكره', 1),
#              ('جن', 2),
#              ('هيستسلم', 4),
#              ('طول', 97),
#              ('فبص', 2),
#              ('للارض', 8),
#              ('ورفع', 3),
#              ('الزنط', 2),
#              ('بتاع', 9),
#              ('الجاكت', 1),
#              ('بتاعه', 7),
#              ('غطي', 2),
#              ('راسه', 13),
#              ('طريقه', 19),
#              ('الصفات', 2),
#              ('السيئه', 1),
#              ('اتوصفتله', 1),
#              ('بيحكم', 3),
#              ('محدش', 52),
#              ('ابدا', 120),
#              ('حاول', 30),
#              ('يعرفه', 2),
#              ('كانسان', 2),
#              ('علشان', 261),
#              ('كده', 309),
#              ('عزل', 1),
#              ('نفسه', 64),
#              ('ذنبه', 6),
#              ('اتشوه', 1),
#              ('حادثه', 5),
#              ('غيرت', 5),
#              ('حياته', 19),
#              ('عنده', 57),
#              ('سنه', 25),
#              ('ابوه', 61),
#              ('بيكرهه', 2),
#              ('وماصدق', 1),
#              ('الحادثه', 15),
#              ('حصلت', 11),
#              ('فطرده', 1),
#              ('حس', 19),
#              ('بحب', 15),
#              ('حنيه', 2),
#              ('حتي', 92),
#              ('امه', 38),
#              ('محبتوش', 1),
#              ('ولما', 44),
#              ('طرده', 2),
#              ('دافعتش', 1),
#              ('ابنها', 16),
#              ('عايش', 8),
#              ('وتقبل', 2),
#              ('عيشته', 2),
#              ('ووحدته', 1),
#              ('وراضي', 2),
#              ('بيها', 52),
#              ('وبيساعد', 1),
#              ('طريق', 3),
#              ('شغله', 26),
#              ('ضعيف', 6),
#              ('محتاج', 25),
#              ('لمساعده', 1),
#              ('يوم', 143),
#              ('احتاج', 1),
#              ('مساعده', 4),
#              ('لقيش', 1),
#              ('جنبه', 31),
#              ('بيتمشي', 2),
#              ('لمكان', 2),
#              ('فاضي', 8),
#              ('شجر', 1),
#              ('وبس', 54),
#              ('لاحظ', 3),
#              ('متحاوطه', 1),
#              ('بالشجر', 1),
#              ('والنخيل', 1),
#              ('كانت', 131),
#              ('مشهوره', 1),
#              ('بيه', 47),
#              ('وكلها', 1),
#              ('جناين', 1),
#              ('وغيطان', 1),
#              ('الفلاحين', 2),
#              ('والبلد', 1),
#              ('بالظبط', 9),
#              ('قعد', 9),
#              ('وسرح', 1),
#              ('وافتكر', 4),
#              ('مغيرتهاش', 1),
#              ('محبوب', 1),
#              ('ورجع', 11),
#              ('لذكرياته', 2),
#              ('لورا', 5),
#              ('والحادثه', 1),
#              ('اجازه', 17),
#              ('الصيف', 2),
#              ('وادهم', 73),
#              ('اوضته', 20),
#              ('مسموحله', 1),
#              ('يخرج', 10),
#              ('اضيق', 2),
#              ('الظروف', 5),
#              ('وفي', 55),
#              ('اخر', 61),
#              ('الليل', 26),
#              ('بالتحديد', 1),
#              ('دخل', 59),
#              ('متنرفز', 2),
#              ('الاب', 27),
#              ('حسين', 200),
#              ('سيادتك', 16),
#              ('نايم', 17),
#              ('واخوك', 1),
#              ('احمد', 87),
#              ('بره', 92),
#              ('اعلم', 4),
#              ('جراله', 3),
#              ('بيسهر', 1),
#              ('اصحابه', 11),
#              ('لوقت', 1),
#              ('متأخر', 3),
#              ('كمان', 80),
#              ('بترد', 6),
#              ('عليا؟', 4),
#              ('قوم', 12),
#              ('فز', 1),
#              ('مكانك', 2),
#              ('وانزل', 2),
#              ('ومترجعش', 1),
#              ('البيت', 99),
#              ('اتفضل', 22),
#              ('اخوه', 19),
#              ('سهران', 2),
#              ('نايت', 1),
#              ('كلب', 8),
#              ('وزمانه', 1),
#              ('سكران', 6),
#              ('حاسس', 20),
#              ('بالوقت', 1),
#              ('يقدرش', 1),
#              ('يقول', 13),
#              ('لابوه', 6),
#              ('شيء', 4),
#              ('بيصدقش', 1),
#              ('ابنه', 30),
#              ('المبجل', 1),
#              ('راحله', 1),
#              ('وفعلا', 34),
#              ('لقاه', 5),
#              ('وسنده', 2),
#              ('ووصله', 2),
#              ('لحد', 124),
#              ('عربيته', 15),
#              ('وطلب', 9),
#              ('يسمحله', 1),
#              ('يسوق', 1),
#              ('يروحو', 2),
#              ('بتاكسي', 1),
#              ('هات', 2),
#              ('المفاتيح', 1),
#              ('وانا', 156),
#              ('اسوق', 3),
#              ('واخيرا', 43),
#              ('الفرصه', 6),
#              ('جاتلك', 2),
#              ('تسوق', 2),
#              ('عربيتي', 3),
#              ('صح؟', 30),
#              ('بعدك', 4),
#              ('بيتكلم', 15),
#              ('بيطوح', 1),
#              ('هتعرف', 4),
#              ('سمحت', 20),
#              ('طب', 33),
#              ('بلاش', 12),
#              ('تعال', 33),
#              ('نركب', 2),
#              ('تاكسي', 5),
#              ('هسوق', 1),
#              ('عاجبك', 6),
#              ('روح', 17),
#              ('مشي', 24),
#              ('ابوك', 27),
#              ('يقولي', 2),
#              ('سيبت', 4),
#              ('اخوك', 6),
#              ('اركب', 1),
#              ('وربنا', 6),
#              ('يستر', 2),
#              ('ساق', 1),
#              ('بسرعه', 51),
#              ('مجنونه', 4),
#              ('جمبه', 1),
#              ('بيحاول', 20),
#              ('يخليه', 3),
#              ('يهدي', 4),
#              ('مجنون', 5),
#              ('بحاجه', 8),
#              ('خاف', 6),
#              ('وفك', 1),
#              ('حزامه', 5),
#              ('يعرف', 10),
#              ('لحزام', 1),
#              ('يربطهوله', 1),
#              ('وربطله', 1),
#              ('الحزام', 3),
#              ('للاسف', 6),
#              ('ملحقش', 2),
#              ('يربط', 1),
#              ('لان', 48),
#              ('اللحظه', 7),
#              ('فقد', 3),
#              ('السيطره', 2),
#              ('والعربيه', 1),
#              ('لفت', 3),
#              ('بيهم', 7),
#              ('وخبطت', 2),
#              ('نقل', 2),
#              ('محمله', 1),
#              ('الواح', 2),
#              ('زجاج', 1),
#              ('وطبعا', 23),
#              ('رابط', 2),
#              ('فطار', 13),
#              ('زجاجها', 1),
#              ('القدماني', 1),
#              ('اتكسر', 4),
#              ('ولبس', 1),
#              ('النقل', 4),
#              ('الزجاج', 1),
#              ('وفوقه', 1),
#              ('وقفت', 19),
#              ('وحاولو', 1),
#              ('يطلعو', 1),
#              ('لانها', 27),
#              ('بدات', 6),
#              ('تولع', 2),
#              ('طلعوه', 2),
#              ('وراحو', 7),
#              ('لادهم', 30),
#              ('القزاز', 3),
#              ('مغطيه', 2),
#              ('وتقريبا', 7),
#              ('بينزف', 4),
#              ('حته', 8),
#              ('حاولو', 3),
#              ('يشدو', 1),
#              ('بيحركوه', 1),
#              ('بيدخل', 1),
#              ('جسمه', 9),
#              ('اكتر', 125),
#              ('سابوه', 3),
#              ('العربيتين', 1),
#              ('واحده', 65),
#              ('انفجرت', 1),
#              ('التانيه', 1),
#              ('هتنفجر', 3),
#              ('فشدوه', 1),
#              ('وطلعوه', 1),
#              ('والقزاز', 2),
#              ('نقلوهم', 1),
#              ('المستشفي', 51),
#              ('وهناك', 6),
#              ('اتصلوا', 1),
#              ('باهلهم', 1),
#              ('اخد', 32),
#              ('مراته', 34),
#              ('حنان', 199),
#              ('للمستشفي', 7),
#              ('وطلعوا', 4),
#              ('للدكتور', 7),
#              ('طمني', 1),
#              ('ابني', 58),
#              ('اخباره', 2),
#              ('الدكتور', 143),
#              ('اتنين', 8),
#              ('فيهم', 12),
#              ('حالته', 14),
#              ('كويسه', 26),
#              ('فيدوب', 1),
#              ('خبطه', 2),
#              ('بسيطه', 7),
#              ('وضلع', 1),
#              ('مكسورين', 1),
#              ('التاني', 5),
#              ('صعبه', 7),
#              ('خرج', 37),
#              ('سوء', 1),
#              ('حظه', 2),
#              ('نزل', 12),
#              ('قزاز', 6),
#              ('فده', 7),
#              ('سببله', 1),
#              ('جروح', 7),
#              ('كتيره', 11),
#              ('والمشكله', 2),
#              ('الجروح', 17),
#              ('اخدهم', 6),
#              ('الخطيره', 1),
#              ('خطيره؟', 1),
#              ('ايوه', 69),
#              ('الكبير', 6),
#              ('زي', 109),
#              ('قلتلك', 14),
#              ('مهم', 13),
#              ('مات', 2),
#              ('يريح', 5),
#              ('محتاجكم', 1),
#              ('بقولك', 16),
#              ('وخرج', 21),
#              ('قدامهم', 1),
#              ('وقبل', 6),
#              ('وطي', 2),
#              ('سامع', 6),
#              ('كلمه', 31),
#              ('هتبقي', 11),
#              ('يبقي', 112),
#              ('جواك', 5),
#              ('براك', 2),
#              ('جوه', 18),
#              ('وبره', 1),
#              ('وبكده', 1),
#              ('عمر', 14),
#              ('هيحبك', 3),
#              ('وهتفضل', 2),
#              ('مكروه', 2),
#              ('سابه', 7),
#              ('وراح', 29),
#              ('لابنه', 3),
#              ('حبيبه', 9),
#              ('بص', 36),
#              ('ناحيه', 14),
#              ('نظره', 14),
#              ('غريق', 1),
#              ('بيتعلق', 2),
#              ('بقشه', 1),
#              ('تكلمه', 12),
#              ('مره', 93),
#              ('بطلت', 9),
#              ('سنين', 23),
#              ('منعت', 2),
#              ('الكلام', 35),
#              ('نهائي', 34),
#              ('كلمها', 3),
#              ('بصلها', 20),
#              ('ونفسه', 3),
#              ('يسمع', 6),
#              ('صوتها', 8),
#              ('تقوله', 6),
#              ('ووطت', 2),
#              ('ودنه', 2),
#              ('وهمست', 3),
#              ('موت', 4),
#              ('بقي', 198),
#              ('غمض', 6),
#              ('عينه', 9),
#              ('صمت', 14),
#              ('كلمتها', 3),
#              ('ليه٣', 2),
#              ('٢', 2),
#              ('سابته', 8),
#              ('وخرجت', 2),
#              ('وراحت', 5),
#              ('لجوزها', 8),
#              ('وابنها', 4),
#              ('سايق', 10),
#              ('هيموتنا', 1),
#              ('الاتنين', 42),
#              ('فضلت', 25),
#              ('اقوله', 4),
#              ('المجنون', 14),
#              ('يقتلنا', 1),
#              ('حبيبي', 25),
#              ('اهدي', 19),
#              ('انتقم', 1),
#              ('اشد', 1),
#              ('انتقام', 1),
#              ('الحمد', 9),
#              ('لله', 10),
#              ('انك', 131),
#              ('طلعت', 9),
#              ('سليم', 2),
#              ('يهمني', 3),
#              ('ارتاح', 8),
#              ('والام', 2),
#              ('قعدت', 13),
#              ('تنطق', 4),
#              ('انتي', 306),
#              ('مصدقاني', 1),
#              ('وهتفرق', 1),
#              ('مصدقك', 3),
#              ('بتحبيه', 2),
#              ('عمرك', 31),
#              ('حبيتي', 2),
#              ('٣', 25),
#              ('قولي', 22),
#              ('حاله', 20),
#              ('بالظبط؟', 23),
#              ('كسر', 3),
#              ('ضلوعه', 1),
#              ('وكسر', 2),
#              ('رجله', 4),
#              ('واشتباه', 1),
#              ('نزيف', 4),
#              ('المخ', 3),
#              ('والجروح', 2),
#              ('معظم', 4),
#              ('اثارها', 2),
#              ('هتخف', 1),
#              ('تختفي', 3),
#              ('لأ', 41),
#              ('وهيحتاج', 1),
#              ('لعمليات', 1),
#              ('تجميل', 4),
#              ('وخصوصا', 7),
#              ('عميقه', 1),
#              ('وهتشوه', 1),
#              ('متعالجتش', 1),
#              ('واتعملها', 1),
#              ('الموضوع', 37),
#              ('مكلف', 1),
#              ('غني', 3),
#              ('وده', 56),
#              ('ابنك', 49),
#              ('ومستقبله', 1),
#              ('هيكلف', 1),
#              ('نعدي', 1),
#              ('الف', 8),
#              ('هديلك', 1),
#              ('بشرط', 4),
#              ('ميخفش', 1),
#              ('تفضل', 9),
#              ('مفتوحه', 1),
#              ('وانه', 19),
#              ('يتشوه', 1),
#              ('لدرجه', 19),
#              ('ابليس', 4),
#              ('يستعيذ', 3),
#              ('افندم', 16),
#              ('سمعته', 2),
#              ('خيانه', 2),
#              ('مهنيه', 1),
#              ('هتنفذ', 2),
#              ('غيرك', 16),
#              ('هينفذ', 1),
#              ('ويستفاد', 1),
#              ('الفلوس', 5),
#              ('اذنك', 23),
#              ('الدكتور؛', 1),
#              ('استني', 37),
#              ('وعطا', 1),
#              ('وايه', 18),
#              ('يضمني', 1),
#              ('متبلغش', 1),
#              ('عني', 26),
#              ('وتوديني', 1),
#              ('داهيه', 5),
#              ('اكتبلك', 1),
#              ('اقرار', 2),
#              ('اني', 154),
#              ('موافق', 11),
#              ('تعمل', 26),
#              ('حاجه', 308),
#              ('طلبه', 2),
#              ('مثلا', 8),
#              ('يتدربوا', 1),
#              ('عايزه', 137),
#              ('تضمن', 1),
#              ('نفسك', 46),
#              ('عليها', 83),
#              ('اتفقنا', 25),
#              ('بدأت', 5),
#              ('رحله', 7),
#              ('العذاب', 5),
#              ('لعيل', 1),
#              ('الخطأ', 1),
#              ('ارتكبه', 3),
#              ('يكرهه', 1),
#              ('الد', 2),
#              ('كتور', 2),
#              ('لكام', 2),
#              ('ممرضه', 2),
#              ('اخترتكم', 1),
#              ('انتو', 31),
#              ('التلاته', 3),
#              ('هتكسبكوا', 1),
#              ('كتير', 73),
#              ('سؤال', 21),
#              ('موافقين؟', 1),
#              ('الممرضات', 10),
#              ('فلوس', 12),
#              ('موافقين', 1),
#              ('كويس', 36),
#              ('تعالو', 4),
#              ('معايا', 69),
#              ('بدؤا', 4),
#              ('علاجه', 2),
#              ('وجبسوله', 1),
#              ('الكسور', 1),
#              ('واتاكدوا', 1),
#              ('جه', 28),
#              ('دكتور', 18),
#              ('التجميل', 1),
#              ('مسؤل', 3),
#              ('خياطه', 1),
#              ('جروحه', 7),
#              ('بنات', 9),
#              ('هاتو', 1),
#              ('نعالج', 1),
#              ('اخدوه', 4),
#              ('اوضه', 25),
#              ('وبدؤا', 6),
#              ('ينفذوا', 1),
#              ('خطتهم', 1),
#              ('عايزكم', 2),
#              ('تهتموا', 1),
#              ('بجروحه', 2),
#              ('وتحطوا', 1),
#              ('فتيل', 2),
#              ('وقطن', 1),
#              ('تقفل', 3),
#              ('مفهوم', 2),
#              ('بس٣', 3),
#              ('قولنا', 1),
#              ('الاول', 43),
#              ('اربطوه', 1),
#              ('لحسن', 1),
#              ('يفكر', 14),
#              ('يهرب', 2),
#              ('فعلا', 71),
#              ('ربطوا', 1),
#              ('ايديه', 26),
#              ('يفتحوا', 1),
#              ('ويحطوا', 2),
#              ('الفتيل', 2),
#              ('والقطن', 2),
#              ('تلتئمش', 1),
#              ('متخيل', 5),
#              ('قمه', 4),
#              ('غلطان', 7),
#              ('بيحس', 11),
#              ('خلاص', 88),
#              ('هيموت', 6),
#              ('ايديهم', 3),
#              ('خلصوا', 4),
#              ('وسابوه', 1),
#              ('وادوله', 1),
#              ('الادويه', 1),
#              ('ياخدها', 10),
#              ('طلع', 24),
#              ('النهار', 35),
#              ('ودخل', 22),
#              ('معرفش', 22),
#              ('سر', 1),
#              ('العداء', 1),
#              ('بينك', 3),
#              ('وبين', 10),
#              ('بيكرهك', 1),
#              ('وسوري', 1),
#              ('شخصي', 1),
#              ('ينطق', 9),
#              ('مقدرش', 19),
#              ('عطاله', 2),
#              ('حقنه', 1),
#              ('يتحرك', 9),
#              ('متحاولش', 2),
#              ('تقاوم', 1),
#              ('الحقنه', 2),
#              ('هتعملك', 1),
#              ('شلل', 1),
#              ('مؤقت', 1),
#              ('هتقدر', 4),
#              ('تتحرك', 4),
#              ('تتكلم', 7),
#              ('هتحس', 1),
#              ('بيحصل', 8),
#              ('اسف', 39),
#              ('دفع', 1),
#              ('مبلغ', 2),
#              ('كبير', 21),
#              ('مقابل', 3),
#              ('والا', 8),
#              ('كنت', 129),
#              ('عطيتك', 1),
#              ('بنج', 1),
#              ('استعد', 2),
#              ('دخلو', 7),
#              ('وخدو', 1),
#              ('لاوضه', 2),
#              ('تانيه', 27),
#              ('استنونو', 1),
#              ('غمضوله', 1),
#              ('عنيه', 22),
#              ('قفلو', 1),
#              ('يفتحهم', 1),
#              ('سمع', 17),
#              ('اصوات', 2),
#              ('عمركم', 1),
#              ('بتتدربو', 1),
#              ('جثث', 1),
#              ('النهارده', 32),
#              ('هتتدربو', 1),
#              ('جسم', 4),
#              ('حي', 3),
#              ('وبينزف', 1),
#              ('رأيكم', 1),
#              ('المفاجأة', 2),
#              ('لطلبه', 1),
#              ('فرحانين', 2),
#              ('الطلبه', 11),
#              ('طيب', 87),
#              ('متبنج', 1),
#              ('وموافق', 1),
#              ('تدريبنا', 1),
#              ('غيبوبه', 6),
#              ('تعتبره', 1),
#              ('ميت', 7),
#              ('اكلينيكيا', 2),
#              ('هيحس', 1),
#              ('تعمله', 1),
#              ('هنبدا', 1),
#              ('نتعلم', 1),
#              ('اشكال', 2),
#              ('الغرز', 2),
#              ('ونستعمل', 1),
#              ('غرزه', 1),
#              ('امته', 1),
#              ('يصرخ', 6),
#              ('يقولهم', 2),
#              ('وحاسس', 8),
#              ('حرام', 9),
#              ('عليكم', 5),
#              ('قادر', 34),
#              ('بدا', 17),
#              ('يجهز', 4),
#              ('للالم', 1),
#              ('يتحمله', 1),
#              ('الالم', 9),
#              ('الخيال', 2),
#              ('ابر', 1),
#              ('تدخل', 15),
#              ('يحتمل', 1),
#              ('يعمل', 30),
#              ('بدأ', 10),
#              ('يدعي', 1),
#              ('اموت', 5),
#              ('الصريخ', 1),
#              ('كانو', 11),
#              ('مستكترينه', 1),
#              ('يفوق', 4),
#              ('فتح', 24),
#              ('وصحي', 2),
#              ('نومه', 4),
#              ('باب', 16),
#              ...])

# %%
from collections import Counter

word_counts = Counter(tokenizer.word_counts)
print("Most common words:", word_counts.most_common(10))
print("Number of words with count ≥5:", sum(1 for cnt in word_counts.values() if cnt >= 5))
print("Number of words with count <5:", sum(1 for cnt in word_counts.values() if cnt < 5))
# Out:
# Most common words: [('ادهم', 2104), ('ليلي', 1683), ('مش', 1046), ('انا', 834), ('اللي', 670), ('انت', 591), ('علي', 586), ('ده', 505), ('ايه', 471), ('محمود', 393)]
# Number of words with count ≥5: 1686
# Number of words with count <5: 10831

# %%
# def optimize_vocabulary(tokenizer, min_count):
#     # Get words that meet the min_count threshold
#     kept_words = [word for word, cnt in tokenizer.word_counts.items() if cnt >= min_count]
    
#     # Rebuild tokenizer only on these words
#     new_tokenizer = Tokenizer()
#     new_tokenizer.fit_on_texts([" ".join(kept_words)])  # Simpler approach
    
#     print(f"Vocabulary reduced from {len(tokenizer.word_index)} to {len(new_tokenizer.word_index)}")
#     return new_tokenizer

# # Apply vocabulary optimization
# tokenizer = optimize_vocabulary(tokenizer, min_count=2)
# vocab_size = len(tokenizer.word_index) + 1
sequences = tokenizer.texts_to_sequences(corpus)

# %%
vocab_size
# Out:
# 12518

# %%
tokenizer.word_index
# Out:
# {'ادهم': 1,
#  'ليلي': 2,
#  'مش': 3,
#  'انا': 4,
#  'اللي': 5,
#  'انت': 6,
#  'علي': 7,
#  'ده': 8,
#  'ايه': 9,
#  'محمود': 10,
#  'عم': 11,
#  'ايه؟': 12,
#  'ان': 13,
#  'كده': 14,
#  'حاجه': 15,
#  'انتي': 16,
#  'علشان': 17,
#  'دي': 18,
#  'نقطة': 19,
#  'انه': 20,
#  'او': 21,
#  'عايز': 22,
#  'حسين': 23,
#  'حنان': 24,
#  'بقي': 25,
#  'اي': 26,
#  'حد': 27,
#  'تاني': 28,
#  'ليه': 29,
#  'عارف': 30,
#  'وانا': 31,
#  'اني': 32,
#  'يوم': 33,
#  'الدكتور': 34,
#  'عايزه': 35,
#  'ام': 36,
#  'ممكن': 37,
#  'كانت': 38,
#  'انك': 39,
#  'كنت': 40,
#  'اكتر': 41,
#  'لحد': 42,
#  'ابدا': 43,
#  '؟': 44,
#  'وهيا': 45,
#  'يعني': 46,
#  'يبقي': 47,
#  'زي': 48,
#  'شويه': 49,
#  'انها': 50,
#  'ومش': 51,
#  'البيت': 52,
#  'صبري': 53,
#  'وبعدين': 54,
#  'طول': 55,
#  'مره': 56,
#  'ليه؟': 57,
#  'اول': 58,
#  'دلوقتي': 59,
#  'حتي': 60,
#  'بره': 61,
#  'مني': 62,
#  'قوي': 63,
#  'جدا': 64,
#  'خلاص': 65,
#  'احمد': 66,
#  'طيب': 67,
#  'ابوها': 68,
#  'احنا': 69,
#  'عليها': 70,
#  'لازم': 71,
#  'كمان': 72,
#  'الكل': 73,
#  'مصطفي': 74,
#  'بعيد': 75,
#  'طبعا': 76,
#  'وادهم': 77,
#  'كتير': 78,
#  'شيئ': 79,
#  'منك': 80,
#  'فعلا': 81,
#  'البلد': 82,
#  'المهم': 83,
#  'كلها': 84,
#  'ايوه': 85,
#  'معايا': 86,
#  'وانت': 87,
#  'لانه': 88,
#  'لسه': 89,
#  'عارفه': 90,
#  'واحده': 91,
#  'نفسه': 92,
#  'مفيش': 93,
#  'عليا': 94,
#  'ابوه': 95,
#  'اخر': 96,
#  'اصلا': 97,
#  'ابوكي': 98,
#  'معاه': 99,
#  'يكون': 100,
#  'دخل': 101,
#  'كفايه': 102,
#  'ازاي': 103,
#  'ابني': 104,
#  'كله': 105,
#  'عنده': 106,
#  'الباب': 107,
#  'وده': 108,
#  'برضه': 109,
#  'اخيرا': 110,
#  'يالا': 111,
#  'وفي': 112,
#  'ده؟': 113,
#  'حضرتك': 114,
#  'وبس': 115,
#  'وليلي': 116,
#  'معاك': 117,
#  'بابا': 118,
#  'عمري': 119,
#  'محدش': 120,
#  'بيها': 121,
#  'بسرعه': 122,
#  'المستشفي': 123,
#  'ارجوك': 124,
#  'بحبك': 125,
#  'حمدي': 126,
#  'وكل': 127,
#  'عنه': 128,
#  'ابنك': 129,
#  'وانتي': 130,
#  'زياد': 131,
#  'لان': 132,
#  'ايده': 133,
#  'وبعدها': 134,
#  'ومشي': 135,
#  'واقف': 136,
#  'واول': 137,
#  'بيه': 138,
#  'كده؟': 139,
#  'اه': 140,
#  'نفسك': 141,
#  'ابو': 142,
#  'عندك': 143,
#  'مين': 144,
#  'معاها': 145,
#  'فين': 146,
#  'ولما': 147,
#  'خايف': 148,
#  'واخيرا': 149,
#  'الاول': 150,
#  'بالك': 151,
#  'الاتنين': 152,
#  'نفسي': 153,
#  'لأ': 154,
#  'حصل': 155,
#  'الناس': 156,
#  'عمره': 157,
#  'وقف': 158,
#  'بنتي': 159,
#  'لحظه': 160,
#  'وقت': 161,
#  'تكون': 162,
#  'اسف': 163,
#  'الارض': 164,
#  'يمكن': 165,
#  'امه': 166,
#  'قلبه': 167,
#  'ازاي؟': 168,
#  'خرج': 169,
#  'الموضوع': 170,
#  'استني': 171,
#  'امال': 172,
#  'بكره': 173,
#  'راجل': 174,
#  'الدنيا': 175,
#  'فين؟': 176,
#  'بص': 177,
#  'كويس': 178,
#  'مكانه': 179,
#  'الكلام': 180,
#  'النهار': 181,
#  'صح': 182,
#  'ساره': 183,
#  'اهوه': 184,
#  'مكنش': 185,
#  'وفعلا': 186,
#  'مراته': 187,
#  'نهائي': 188,
#  'قادر': 189,
#  'ديما': 190,
#  'اكيد': 191,
#  'بجد': 192,
#  'مكنتش': 193,
#  'حاليا': 194,
#  'طب': 195,
#  'تعال': 196,
#  'اعمل': 197,
#  'ماكس': 198,
#  'بنتك': 199,
#  'شَرْطَة': 200,
#  'العربيه': 201,
#  'الصبح': 202,
#  'اخد': 203,
#  'النهارده': 204,
#  'ماشي': 205,
#  'سُفْلِيَّة': 206,
#  'وشه': 207,
#  'جنبه': 208,
#  'كلمه': 209,
#  'عمرك': 210,
#  'انتو': 211,
#  'كلهم': 212,
#  'صغير': 213,
#  'سابها': 214,
#  'عملت': 215,
#  'حياتي': 216,
#  'حضنه': 217,
#  'معاكي': 218,
#  'والكل': 219,
#  'ساعتها': 220,
#  'المفروض': 221,
#  'مكان': 222,
#  'العيال': 223,
#  'حاول': 224,
#  'ابنه': 225,
#  'صح؟': 226,
#  'لادهم': 227,
#  'يعمل': 228,
#  'الوقت': 229,
#  'عنها': 230,
#  'جوزها': 231,
#  'ويدوب': 232,
#  'عنك': 233,
#  'عايزك': 234,
#  'جنبها': 235,
#  'الزعيم': 236,
#  'فاهم': 237,
#  'وراح': 238,
#  'تيجي': 239,
#  'الحب': 240,
#  'دخلت': 241,
#  'قلت': 242,
#  'كام': 243,
#  'ايديها': 244,
#  'بنته': 245,
#  'اهلا': 246,
#  'جه': 247,
#  'تاني؟': 248,
#  'غصب': 249,
#  'ولسه': 250,
#  'امتي': 251,
#  'رد': 252,
#  'فكره': 253,
#  'هاه؟': 254,
#  'وكان': 255,
#  'اوعي': 256,
#  'بينا': 257,
#  'يتكلم': 258,
#  'ساعه': 259,
#  'قدامه': 260,
#  'الاب': 261,
#  'ابوك': 262,
#  'لانها': 263,
#  'تانيه': 264,
#  'قدام': 265,
#  'معاهم': 266,
#  'يجي': 267,
#  'اليوم': 268,
#  'وراه': 269,
#  'اعرف': 270,
#  'غلط': 271,
#  'كلام': 272,
#  'يمشي': 273,
#  'شغله': 274,
#  'الليل': 275,
#  'كويسه': 276,
#  'عني': 277,
#  'تعمل': 278,
#  'ايديه': 279,
#  'بدري': 280,
#  'هيكون': 281,
#  'عندي': 282,
#  'فضل': 283,
#  'جاي': 284,
#  'حب': 285,
#  'عمي': 286,
#  'جنبك': 287,
#  'الايام': 288,
#  'وصل': 289,
#  'عادي': 290,
#  'صغيره': 291,
#  'سنه': 292,
#  'محتاج': 293,
#  'فضلت': 294,
#  'حبيبي': 295,
#  '٣': 296,
#  'اتفقنا': 297,
#  'اوضه': 298,
#  'عيل': 299,
#  'ارجوكي': 300,
#  'افضل': 301,
#  'جوزك': 302,
#  'بيته': 303,
#  'مشي': 304,
#  'طلع': 305,
#  'فتح': 306,
#  'قال': 307,
#  'دي؟': 308,
#  'قصدي': 309,
#  'كنتي': 310,
#  'وعلشان': 311,
#  'جنبي': 312,
#  'لوحده': 313,
#  'وبعد': 314,
#  'مشوه': 315,
#  'وطبعا': 316,
#  'سنين': 317,
#  'بالظبط؟': 318,
#  'اذنك': 319,
#  'هاه': 320,
#  'مسك': 321,
#  'قرب': 322,
#  'خالص': 323,
#  'نفسها': 324,
#  'عليكي': 325,
#  'اقولك': 326,
#  'رايح': 327,
#  'ليا': 328,
#  'موجود': 329,
#  'حياتها': 330,
#  'هيبقي': 331,
#  'اتفضل': 332,
#  'قولي': 333,
#  'ودخل': 334,
#  'معرفش': 335,
#  'عنيه': 336,
#  'واكتر': 337,
#  'فرصه': 338,
#  'لقي': 339,
#  'هقدر': 340,
#  'بيتي': 341,
#  'وان': 342,
#  'اخدت': 343,
#  'شهر': 344,
#  'اسفه': 345,
#  'العيله': 346,
#  'آيه': 347,
#  'الحمل': 348,
#  'دول': 349,
#  'الطريق': 350,
#  'المدير': 351,
#  'وخرج': 352,
#  'سؤال': 353,
#  'كبير': 354,
#  'تبقي': 355,
#  'جواه': 356,
#  'راحت': 357,
#  'ماهو': 358,
#  'لوحدي': 359,
#  'شاف': 360,
#  'ودلوقتي': 361,
#  'الاخر': 362,
#  'قاعد': 363,
#  'اكون': 364,
#  'جري': 365,
#  'بقي؟': 366,
#  'بيت': 367,
#  'حاولت': 368,
#  'ليك': 369,
#  'تقولي': 370,
#  'وابوها': 371,
#  'ابن': 372,
#  'عليهم': 373,
#  'اهو': 374,
#  'سلام': 375,
#  'شكله': 376,
#  'فتره': 377,
#  'اما': 378,
#  'ابتسم': 379,
#  'اوضته': 380,
#  'حاسس': 381,
#  'سمحت': 382,
#  'بيحاول': 383,
#  'بصلها': 384,
#  'حاله': 385,
#  'ومشيت': 386,
#  'وهما': 387,
#  'مشيت': 388,
#  'فاكر': 389,
#  'ابقي': 390,
#  'خليك': 391,
#  'ابعد': 392,
#  'ابويا': 393,
#  'بتقول': 394,
#  'لليلي': 395,
#  'بينهم': 396,
#  'طلب': 397,
#  'رقبته': 398,
#  'البيبي': 399,
#  'دادو': 400,
#  'قربت': 401,
#  'رفض': 402,
#  'انهم': 403,
#  'صوت': 404,
#  'سابهم': 405,
#  'عايزني': 406,
#  'طريقه': 407,
#  'حياته': 408,
#  'حس': 409,
#  'اخوه': 410,
#  'وقفت': 411,
#  'اهدي': 412,
#  'وانه': 413,
#  'لدرجه': 414,
#  'مقدرش': 415,
#  'حاضر': 416,
#  'الفطار': 417,
#  'ايدها': 418,
#  'السرير': 419,
#  'حبيبته': 420,
#  'تقريبا': 421,
#  'طويله': 422,
#  'حق': 423,
#  'زعلان': 424,
#  'الشغل': 425,
#  'الكلب': 426,
#  'عدي': 427,
#  'خير': 428,
#  'المره': 429,
#  'لاني': 430,
#  'يدوب': 431,
#  'يدخل': 432,
#  'مراتك': 433,
#  'الحمام': 434,
#  'مدير': 435,
#  'تقدر': 436,
#  'حواليه': 437,
#  'جوه': 438,
#  'وايه': 439,
#  'دكتور': 440,
#  'يقدر': 441,
#  'مجرد': 442,
#  'بتعيط': 443,
#  'عندها': 444,
#  'للحظه': 445,
#  'اولا': 446,
#  'تقول': 447,
#  'تعيط': 448,
#  'الشرطه': 449,
#  'يعني؟': 450,
#  'بكل': 451,
#  'اتكلم': 452,
#  'وهنا': 453,
#  'مهمه': 454,
#  'اجازه': 455,
#  'نايم': 456,
#  'روح': 457,
#  'الجروح': 458,
#  'سمع': 459,
#  'بدا': 460,
#  'مالك': 461,
#  'خلص': 462,
#  'منهم': 463,
#  'هعمل': 464,
#  'هدومه': 465,
#  'جرح': 466,
#  'جديد': 467,
#  'ناس': 468,
#  'مالك؟': 469,
#  'وعلي': 470,
#  'جنب': 471,
#  'فيا': 472,
#  'وليه': 473,
#  'جديده': 474,
#  'مراتي': 475,
#  'جامد': 476,
#  'قلبي': 477,
#  'وامها': 478,
#  'الوضع': 479,
#  'معلش': 480,
#  'تعبان': 481,
#  'ابنها': 482,
#  'سيادتك': 483,
#  'بقولك': 484,
#  'افندم': 485,
#  'غيرك': 486,
#  'باب': 487,
#  'فاق': 488,
#  'امبارح': 489,
#  'متشكر': 490,
#  'وجه': 491,
#  'عقله': 492,
#  'وشها': 493,
#  'شافها': 494,
#  'عمل': 495,
#  'الاوضه': 496,
#  'تعالي': 497,
#  'سبق': 498,
#  'بيتها': 499,
#  'امشي': 500,
#  'جت': 501,
#  'اتفاجئ': 502,
#  'خرجت': 503,
#  'اقرب': 504,
#  'اب': 505,
#  'خاطري': 506,
#  'مستعد': 507,
#  'تليفونه': 508,
#  'بيتك': 509,
#  'العصابه': 510,
#  'السبب': 511,
#  'امها': 512,
#  'طويل': 513,
#  'ظابط': 514,
#  'باي': 515,
#  'اذنكم': 516,
#  'خلي': 517,
#  'الحادثه': 518,
#  'بحب': 519,
#  'عربيته': 520,
#  'بيتكلم': 521,
#  'تدخل': 522,
#  'مستغرب': 523,
#  'سكت': 524,
#  'وبص': 525,
#  'امل': 526,
#  'تشوف': 527,
#  'فيك': 528,
#  'امتي؟': 529,
#  'هنا؟': 530,
#  'يروح': 531,
#  'استغرب': 532,
#  'ينفع': 533,
#  'عرفت': 534,
#  'بعدها': 535,
#  'ستي': 536,
#  'يرد': 537,
#  'شغل': 538,
#  'حلم': 539,
#  'ووقف': 540,
#  'حضنك': 541,
#  'سيبك': 542,
#  'طعم': 543,
#  'وساعتها': 544,
#  'حياتك': 545,
#  'اعيش': 546,
#  'المكان': 547,
#  'ليله': 548,
#  'غيره': 549,
#  'احسن': 550,
#  'بيك': 551,
#  'عيال': 552,
#  'وسط': 553,
#  'اشوف': 554,
#  'انا؟': 555,
#  'حالته': 556,
#  'قلتلك': 557,
#  'عمر': 558,
#  'ناحيه': 559,
#  'نظره': 560,
#  'صمت': 561,
#  'المجنون': 562,
#  'يفكر': 563,
#  'وفضل': 564,
#  'وخلاص': 565,
#  'قومي': 566,
#  'واهو': 567,
#  'قولتلك': 568,
#  'قلب': 569,
#  'زمان': 570,
#  'اسمه': 571,
#  'فات': 572,
#  'الولد': 573,
#  'ضحك': 574,
#  'الظاهر': 575,
#  'سبب': 576,
#  'مين؟': 577,
#  'الشارع': 578,
#  'اسمع': 579,
#  'خلصت': 580,
#  'قاطعها': 581,
#  'ايدك': 582,
#  'ينفعش': 583,
#  'قدامها': 584,
#  'بالعافيه': 585,
#  'روحي': 586,
#  'انتصرت': 587,
#  'نايمه': 588,
#  'المقدم': 589,
#  'البنت': 590,
#  'الراجل': 591,
#  'حالا': 592,
#  'واللي': 593,
#  'راسه': 594,
#  'يقول': 595,
#  'فطار': 596,
#  'مهم': 597,
#  'قعدت': 598,
#  'جميله': 599,
#  'قفل': 600,
#  'وطلع': 601,
#  'النوم': 602,
#  'المدرسه': 603,
#  'نزلت': 604,
#  'انسان': 605,
#  'شايفه': 606,
#  'اتصل': 607,
#  'حر': 608,
#  'دعوه': 609,
#  'واخد': 610,
#  'غريب': 611,
#  'هيمشي': 612,
#  'داخل': 613,
#  'عرف': 614,
#  'حقك': 615,
#  'وقام': 616,
#  'تاخد': 617,
#  'حواليها': 618,
#  'دماغه': 619,
#  'اقدر': 620,
#  'طلبت': 621,
#  'تعرف': 622,
#  'تمشي': 623,
#  'قصدك': 624,
#  'جوزي': 625,
#  'لابوها': 626,
#  'جيت': 627,
#  'وقته': 628,
#  'الشقه': 629,
#  'كانوا': 630,
#  'يارب': 631,
#  'شاء': 632,
#  'ونزل': 633,
#  'باستغراب': 634,
#  'مسخ': 635,
#  'قوم': 636,
#  'بلاش': 637,
#  'فيهم': 638,
#  'نزل': 639,
#  'تكلمه': 640,
#  'فلوس': 641,
#  'ومين': 642,
#  'شغلي': 643,
#  'هتعمل': 644,
#  'ومهما': 645,
#  'يرجع': 646,
#  'صحي': 647,
#  'الساعه': 648,
#  'وراها': 649,
#  'براحتك': 650,
#  'بتعمل': 651,
#  'لاي': 652,
#  'تماما': 653,
#  'حاجه؟': 654,
#  'بيا': 655,
#  'معنديش': 656,
#  'حست': 657,
#  'حاجات': 658,
#  'فكر': 659,
#  'هتكون': 660,
#  'ويمكن': 661,
#  'ساكت': 662,
#  'بتتكلم': 663,
#  'رجل': 664,
#  'بتقولي': 665,
#  'وحشتني': 666,
#  'مكانها': 667,
#  'حلوه': 668,
#  'حساب': 669,
#  'ادخل': 670,
#  'رائد': 671,
#  'ومحدش': 672,
#  'ماليش': 673,
#  'اناني': 674,
#  'عيلتك': 675,
#  'اتمني': 676,
#  'جريت': 677,
#  'محتاجه': 678,
#  'علاقه': 679,
#  'راحو': 680,
#  'بصت': 681,
#  'تروح': 682,
#  'اهم': 683,
#  'سيبها': 684,
#  'لمراته': 685,
#  'السواق': 686,
#  'كلنا': 687,
#  'النتيجه': 688,
#  'اتصدم': 689,
#  'بطل': 690,
#  'قاطعه': 691,
#  'حصلت': 692,
#  'ورجع': 693,
#  'اصحابه': 694,
#  'كتيره': 695,
#  'هتبقي': 696,
#  'موافق': 697,
#  'بيحس': 698,
#  'الطلبه': 699,
#  'كانو': 700,
#  'لقاها': 701,
#  'علينا': 702,
#  'رايك': 703,
#  'بيحب': 704,
#  'ساعات': 705,
#  'تقرب': 706,
#  'ودي': 707,
#  'مصدق': 708,
#  'الحاجات': 709,
#  'صاحبه': 710,
#  'قالك': 711,
#  'زيك': 712,
#  'وقعد': 713,
#  'قول': 714,
#  'هيخرج': 715,
#  'وعايز': 716,
#  'المجلات': 717,
#  'الاقل': 718,
#  'قاعده': 719,
#  'كلبه': 720,
#  'هتفضل': 721,
#  'الكليه': 722,
#  'عايزاني': 723,
#  'فهمت': 724,
#  'كلامه': 725,
#  'وقال': 726,
#  'بحبه': 727,
#  'ملهاش': 728,
#  'ادهم؟': 729,
#  'رافض': 730,
#  'هينفع': 731,
#  'رجعت': 732,
#  'فكرت': 733,
#  'القائد': 734,
#  'بتقوله': 735,
#  'حضن': 736,
#  'حبيبتي': 737,
#  'وصلت': 738,
#  'يقف': 739,
#  'معانا': 740,
#  'وكنت': 741,
#  'انانيه': 742,
#  'اهل': 743,
#  'عربيه': 744,
#  'بصوت': 745,
#  'يحس': 746,
#  'وحطت': 747,
#  'كنا': 748,
#  'استعداد': 749,
#  'استحاله': 750,
#  'يخرج': 751,
#  'يعرف': 752,
#  'سايق': 753,
#  'لله': 754,
#  'الممرضات': 755,
#  'ياخدها': 756,
#  'وبين': 757,
#  'بدأ': 758,
#  'معدش': 759,
#  'واقفه': 760,
#  'خايفه': 761,
#  'الصغير': 762,
#  'بادهم': 763,
#  'عياله': 764,
#  'فاهمه': 765,
#  'ظهره': 766,
#  'بيعمل': 767,
#  'حمل': 768,
#  'يعيش': 769,
#  'صدره': 770,
#  'بابتسامه': 771,
#  'الدم': 772,
#  'اكبر': 773,
#  'يطلع': 774,
#  'واخده': 775,
#  'بالشكل': 776,
#  'بيحبها': 777,
#  'وقعدت': 778,
#  'وكانت': 779,
#  'بيكي': 780,
#  'عايزاه': 781,
#  'اصحاب': 782,
#  'معرفتش': 783,
#  'هروح': 784,
#  'وقالي': 785,
#  'جايه': 786,
#  'وبصلها': 787,
#  'ومسكت': 788,
#  'لانك': 789,
#  'اروح': 790,
#  'البنات': 791,
#  'خارج': 792,
#  'واخر': 793,
#  'ومره': 794,
#  'موضوع': 795,
#  'قالها': 796,
#  'وافقت': 797,
#  'وانك': 798,
#  'حضنها': 799,
#  'عالي': 800,
#  'ياخد': 801,
#  'الفتحه': 802,
#  'الا': 803,
#  'اعتقد': 804,
#  'وري': 805,
#  'وفضلت': 806,
#  'رجليه': 807,
#  'قالي': 808,
#  'الفرح': 809,
#  'اخدها': 810,
#  'تعبانه': 811,
#  'بتعدي': 812,
#  'فاتت': 813,
#  'والعيال': 814,
#  'كبيره': 815,
#  'همشي': 816,
#  'دور': 817,
#  'الظابط': 818,
#  'العمده': 819,
#  'سياده': 820,
#  'الصغيره': 821,
#  'بتاع': 822,
#  'بالظبط': 823,
#  'قعد': 824,
#  'وطلب': 825,
#  'جسمه': 826,
#  'حبيبه': 827,
#  'بطلت': 828,
#  'عينه': 829,
#  'الحمد': 830,
#  'طلعت': 831,
#  'تفضل': 832,
#  'بنات': 833,
#  'ينطق': 834,
#  'يتحرك': 835,
#  'حرام': 836,
#  'الالم': 837,
#  'كابوس': 838,
#  'موجوده': 839,
#  'شعرها': 840,
#  'لوحدك': 841,
#  'عدت': 842,
#  'بنت': 843,
#  'وساب': 844,
#  'اطلع': 845,
#  'خلينا': 846,
#  'رفضت': 847,
#  'عايزاك': 848,
#  'يقرب': 849,
#  'بنفسك': 850,
#  'مشكله': 851,
#  'كلامها': 852,
#  'الواد': 853,
#  'بتحاول': 854,
#  'اشوفك': 855,
#  'لبس': 856,
#  'وجودي': 857,
#  'بالنسبالي': 858,
#  'قلبها': 859,
#  'مسكت': 860,
#  'وطلعت': 861,
#  'غريبه': 862,
#  'ليلي؟': 863,
#  'مبسوط': 864,
#  'بعدت': 865,
#  'بالليل': 866,
#  'النادي': 867,
#  'مستنياه': 868,
#  'يومين': 869,
#  'متخيله': 870,
#  'نام': 871,
#  'اقول': 872,
#  'انت؟': 873,
#  'ليكي': 874,
#  'تحب': 875,
#  'قدامك': 876,
#  'براحه': 877,
#  'شافه': 878,
#  'واحنا': 879,
#  'تعبت': 880,
#  'وباسها': 881,
#  'الليله': 882,
#  'والمفروض': 883,
#  'وقالها': 884,
#  'الرغم': 885,
#  'بتحبني': 886,
#  'مستنيه': 887,
#  'نتجوز': 888,
#  'للدرجه': 889,
#  'احب': 890,
#  'عيطت': 891,
#  'ومسك': 892,
#  'سمعت': 893,
#  'نسيت': 894,
#  'بخير': 895,
#  'بيقول': 896,
#  'التمن': 897,
#  'بدال': 898,
#  'مديره': 899,
#  'هتيجي': 900,
#  'السكينه': 901,
#  'تعيش': 902,
#  'مصر': 903,
#  'علشانك': 904,
#  'حبك': 905,
#  'يبعد': 906,
#  'العمليات': 907,
#  'علشانه': 908,
#  'حامل': 909,
#  'الكابوس': 910,
#  'يوصل': 911,
#  'ووقفت': 912,
#  'واهي': 913,
#  'اسمي': 914,
#  'عندنا': 915,
#  'لحضرتك': 916,
#  'هكون': 917,
#  'للارض': 918,
#  'عايش': 919,
#  'فاضي': 920,
#  'كلب': 921,
#  'بحاجه': 922,
#  'حته': 923,
#  'اتنين': 924,
#  'صوتها': 925,
#  'سابته': 926,
#  'لجوزها': 927,
#  'ارتاح': 928,
#  'الف': 929,
#  'مثلا': 930,
#  'بيحصل': 931,
#  'والا': 932,
#  'وحاسس': 933,
#  'وحس': 934,
#  'شكلها': 935,
#  'حطت': 936,
#  'ويرجع': 937,
#  'يموت': 938,
#  'شدها': 939,
#  'هاجي': 940,
#  'عنيها': 941,
#  'عمرها': 942,
#  'دموعها': 943,
#  'وهم': 944,
#  'بيدق': 945,
#  'ليها': 946,
#  'النزيف': 947,
#  'صوته': 948,
#  'ذنب': 949,
#  'اتجننت': 950,
#  'قدامي': 951,
#  'شرط': 952,
#  'هقولك': 953,
#  'رايحه': 954,
#  'مليون': 955,
#  'وماكس': 956,
#  'دقايق': 957,
#  'بتحب': 958,
#  'قصاده': 959,
#  'ابتسمت': 960,
#  'مستني': 961,
#  'اديني': 962,
#  'لأ؟': 963,
#  'اختفت': 964,
#  'عذر': 965,
#  'كلامي': 966,
#  'جميل': 967,
#  'باين': 968,
#  'وشك': 969,
#  'بسبب': 970,
#  'بالي': 971,
#  'اتفضلي': 972,
#  'الباقي': 973,
#  'روحت': 974,
#  'زيه': 975,
#  'وعرف': 976,
#  'المشكله': 977,
#  'منين؟': 978,
#  'خطوه': 979,
#  'حبيت': 980,
#  'ضمها': 981,
#  'وممكن': 982,
#  'يكمل': 983,
#  'هفضل': 984,
#  'يشوف': 985,
#  'ابدا٣': 986,
#  'الحياه': 987,
#  'قاطعته': 988,
#  'بقيت': 989,
#  'الحلم': 990,
#  'فاهمه؟': 991,
#  'وسابها': 992,
#  'هيقدر': 993,
#  'يكلمها': 994,
#  'مامت': 995,
#  'يحصل': 996,
#  'يعدي': 997,
#  'بايه؟': 998,
#  'تخرج': 999,
#  'عملته': 1000,
#  ...}

# %%
input_sequences = []
for line in corpus:
    token_list = tokenizer.texts_to_sequences([line])[0]
    for i in range(1, len(token_list)):
        n_gram_sequence = token_list[:i+1]
        input_sequences.append(n_gram_sequence)

# pad sequences 
max_sequence_len = max([len(x) for x in input_sequences])
input_sequences = np.array(pad_sequences(input_sequences, maxlen=max_sequence_len, padding='pre'))

# create predictors and label
x, labels = input_sequences[:,:-1],input_sequences[:,-1]

y = tf.keras.utils.to_categorical(labels, num_classes=vocab_size)

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
embedding_dim = 100 # Size of word embeddings
hidden_dim = 64 # Size of LSTM hidden state

model = Sequential([
    Embedding(input_dim=vocab_size, output_dim=embedding_dim, input_length=max_sequence_len-1),
    Bidirectional(LSTM(hidden_dim, return_sequences=True)),  # Bidirectional LSTM 
    Dropout(0.3),
    Bidirectional(LSTM(hidden_dim//2)),
    Dense(vocab_size, activation='softmax')   # Output layer with softmax for vocabulary
])
adam = Adam(learning_rate=0.01)
model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# c:\Users\my\anaconda3\Lib\site-packages\keras\src\layers\core\embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
epochs = 30

callbacks = [
    EarlyStopping(patience=5, monitor='val_accuracy', mode='max', verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=1e-5, verbose=1)
]

history = model.fit(X_train, y_train, epochs=epochs, validation_data=(X_val,y_val) , callbacks=callbacks, verbose=1)
# Out:
# Epoch 1/30
# 1101/1101 ━━━━━━━━━━━━━━━━━━━━ 163s 142ms/step - accuracy: 0.0233 - loss: 8.4368 - val_accuracy: 0.0255 - val_loss: 8.6229 - learning_rate: 0.0100
# Epoch 2/30
# 1101/1101 ━━━━━━━━━━━━━━━━━━━━ 141s 128ms/step - accuracy: 0.0270 - loss: 8.5243 - val_accuracy: 0.0337 - val_loss: 8.7362 - learning_rate: 0.0100
# Epoch 3/30
# 1101/1101 ━━━━━━━━━━━━━━━━━━━━ 143s 130ms/step - accuracy: 0.0324 - loss: 7.7865 - val_accuracy: 0.0329 - val_loss: 8.7886 - learning_rate: 0.0100
# Epoch 4/30
# 1101/1101 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.0346 - loss: 7.6117
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0019999999552965165.
# 1101/1101 ━━━━━━━━━━━━━━━━━━━━ 146s 132ms/step - accuracy: 0.0346 - loss: 7.6117 - val_accuracy: 0.0378 - val_loss: 8.8553 - learning_rate: 0.0100
# Epoch 5/30
# 1101/1101 ━━━━━━━━━━━━━━━━━━━━ 147s 133ms/step - accuracy: 0.0399 - loss: 7.4081 - val_accuracy: 0.0397 - val_loss: 8.8804 - learning_rate: 0.0020
# Epoch 6/30
# 1101/1101 ━━━━━━━━━━━━━━━━━━━━ 145s 132ms/step - accuracy: 0.0436 - loss: 7.3021 - val_accuracy: 0.0407 - val_loss: 8.9322 - learning_rate: 0.0020
# Epoch 7/30
# 1101/1101 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.0448 - loss: 7.2115
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0003999999724328518.
# 1101/1101 ━━━━━━━━━━━━━━━━━━━━ 153s 139ms/step - accuracy: 0.0448 - loss: 7.2115 - val_accuracy: 0.0418 - val_loss: 8.9795 - learning_rate: 0.0020
# Epoch 8/30
# 1101/1101 ━━━━━━━━━━━━━━━━━━━━ 179s 162ms/step - accuracy: 0.0501 - loss: 7.0576 - val_accuracy: 0.0418 - val_loss: 9.0076 - learning_rate: 4.0000e-04
# Epoch 9/30
# 1101/1101 ━━━━━━━━━━━━━━━━━━━━ 175s 159ms/step - accuracy: 0.0476 - loss: 7.0279 - val_accuracy: 0.0421 - val_loss: 9.0402 - learning_rate: 4.0000e-04
# Epoch 10/30
# 1101/1101 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.0492 - loss: 6.9714
# Epoch 10: ReduceLROnPlateau reducing learning rate to 7.999999215826393e-05.
# 1101/1101 ━━━━━━━━━━━━━━━━━━━━ 174s 158ms/step - accuracy: 0.0492 - loss: 6.9714 - val_accuracy: 0.0422 - val_loss: 9.0848 - learning_rate: 4.0000e-04
# Epoch 11/30
# 1101/1101 ━━━━━━━━━━━━━━━━━━━━ 164s 149ms/step - accuracy: 0.0481 - loss: 6.9616 - val_accuracy: 0.0422 - val_loss: 9.0979 - learning_rate: 8.0000e-05
# Epoch 12/30
# 1101/1101 ━━━━━━━━━━━━━━━━━━━━ 148s 134ms/step - accuracy: 0.0501 - loss: 6.9311 - val_accuracy: 0.0423 - val_loss: 9.1114 - learning_rate: 8.0000e-05
# Epoch 13/30
# 1101/1101 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.0522 - loss: 6.8836
# Epoch 13: ReduceLROnPlateau reducing learning rate to 1.599999814061448e-05.
# 1101/1101 ━━━━━━━━━━━━━━━━━━━━ 149s 135ms/step - accuracy: 0.0522 - loss: 6.8836 - val_accuracy: 0.0421 - val_loss: 9.1235 - learning_rate: 8.0000e-05
# Epoch 14/30
# 1101/1101 ━━━━━━━━━━━━━━━━━━━━ 151s 138ms/step - accuracy: 0.0493 - loss: 6.9101 - val_accuracy: 0.0423 - val_loss: 9.1263 - learning_rate: 1.6000e-05
# Epoch 15/30
# 1101/1101 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.0495 - loss: 6.9323

# %%
seq_len = max_sequence_len - 1

# %%
import sys
import numpy as np
from PyQt5.QtWidgets import (QApplication, QMainWindow, QVBoxLayout, QHBoxLayout, 
                            QLabel, QTextEdit, QPushButton, QWidget, QComboBox,QFileDialog)
from PyQt5.QtCore import Qt
from PyQt5.QtGui import QFont, QColor, QPalette

# Add these methods to your GUI class
def save_model(self):
    options = QFileDialog.Options()
    filename, _ = QFileDialog.getSaveFileName(self, "Save Model", "", "H5 Files (*.h5);;All Files (*)", options=options)
    if filename:
        self.model.save(filename)
        self.statusBar().showMessage(f"Model saved to {filename}")

def load_model(self):
    options = QFileDialog.Options()
    filename, _ = QFileDialog.getOpenFileName(self, "Load Model", "", "H5 Files (*.h5);;All Files (*)", options=options)
    if filename:
        self.model = tf.keras.models.load_model(filename)
        self.statusBar().showMessage(f"Model loaded from {filename}")

class ArabicTextPredictorGUI(QMainWindow):
    def __init__(self, model, tokenizer, seq_len):
        super().__init__()
        self.model = model
        self.tokenizer = tokenizer
        self.seq_len = seq_len
        self.initUI()
        
    def initUI(self):
        # Main window settings
        self.setWindowTitle('Arabic Text Predictor')
        self.setGeometry(100, 100, 800, 600)
        
        # Set Arabic-friendly font
        font = QFont()
        font.setFamily("Arial")  # Or use "Traditional Arabic" if available
        font.setPointSize(14)
        
        # Central widget
        central_widget = QWidget()
        self.setCentralWidget(central_widget)
        
        # Main layout
        main_layout = QVBoxLayout()
        central_widget.setLayout(main_layout)
        
        # Title label
        title_label = QLabel("Arabic Text Prediction")
        title_label.setFont(QFont("Arial", 18, QFont.Bold))
        title_label.setAlignment(Qt.AlignCenter)
        main_layout.addWidget(title_label)
        
        # Text input
        self.text_input = QTextEdit()
        self.text_input.setFont(font)
        self.text_input.setPlaceholderText("Type Arabic text here...")
        self.text_input.setAlignment(Qt.AlignRight)  # Right-align for Arabic
        main_layout.addWidget(self.text_input)
        
        # Prediction controls layout
        controls_layout = QHBoxLayout()
        
        # Prediction type dropdown
        self.pred_type = QComboBox()
        self.pred_type.addItems(["Next Word", "Top 5 Suggestions"])
        self.pred_type.setFont(font)
        controls_layout.addWidget(self.pred_type)
        
        # Predict button
        predict_btn = QPushButton("Predict")
        predict_btn.setFont(font)
        predict_btn.clicked.connect(self.predict_text)
        controls_layout.addWidget(predict_btn)
        
        # Clear button
        clear_btn = QPushButton("Clear")
        clear_btn.setFont(font)
        clear_btn.clicked.connect(self.clear_text)
        controls_layout.addWidget(clear_btn)
        
        save_btn = QPushButton("Save Model")
        save_btn.setFont(font)
        save_btn.clicked.connect(self.save_model)
        controls_layout.addWidget(save_btn)

        load_btn = QPushButton("Load Model")
        load_btn.setFont(font)
        load_btn.clicked.connect(self.load_model)
        controls_layout.addWidget(load_btn)
                
        main_layout.addLayout(controls_layout)
        
        # Prediction output
        self.prediction_output = QTextEdit()
        self.prediction_output.setFont(font)
        self.prediction_output.setAlignment(Qt.AlignRight)
        self.prediction_output.setReadOnly(True)
        
        # Set background color for output
        palette = self.prediction_output.palette()
        palette.setColor(QPalette.Base, QColor(240, 240, 240))
        self.prediction_output.setPalette(palette)
        
        main_layout.addWidget(self.prediction_output)
        
        # Status bar
        self.statusBar().showMessage("Ready")
    
    def predict_text(self):
        input_text = self.text_input.toPlainText().strip()
        
        if not input_text:
            self.statusBar().showMessage("Please enter some text first")
            return
        
        try:
            # Preprocess and tokenize input
            tokens = self.tokenizer.texts_to_sequences([input_text])[0]
            
            if len(tokens) < self.seq_len:
                self.statusBar().showMessage(f"Please enter at least {self.seq_len} words")
                return
            
            # Take the last seq_len tokens
            seq = tokens[-self.seq_len:]
            padded_seq = pad_sequences([seq], maxlen=self.seq_len, padding='pre')
            
            # Make prediction
            pred_type = self.pred_type.currentText()
            
            if pred_type == "Next Word":
                predictions = self.model.predict(padded_seq, verbose=0)
                predicted_idx = np.argmax(predictions, axis=-1)[0]
                predicted_word = self.tokenizer.index_word.get(predicted_idx, "<UNK>")
                
                self.prediction_output.setPlainText(predicted_word)
                self.statusBar().showMessage("Prediction complete")
                
            elif pred_type == "Top 5 Suggestions":
                predictions = self.model.predict(padded_seq, verbose=0)[0]
                top_indices = np.argsort(predictions)[-5:][::-1]
                top_words = [self.tokenizer.index_word.get(idx, "<UNK>") for idx in top_indices]
                top_probs = [predictions[idx] for idx in top_indices]
                
                result = "\n".join([f"{word} ({prob:.2%})" for word, prob in zip(top_words, top_probs)])
                self.prediction_output.setPlainText(result)
                self.statusBar().showMessage("Top 5 predictions generated")
                
        except Exception as e:
            self.statusBar().showMessage(f"Error: {str(e)}")
            self.prediction_output.setPlainText("")
    
    def clear_text(self):
        self.text_input.clear()
        self.prediction_output.clear()
        self.statusBar().showMessage("Cleared")


app = QApplication(sys.argv)

# Set application style (optional)
app.setStyle('Fusion')

# For better Arabic text handling
app.setLayoutDirection(Qt.RightToLeft)

# Create and show the GUI
gui = ArabicTextPredictorGUI(model, tokenizer, seq_len)
gui.show()

sys.exit(app.exec_())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 170
#     167 app.setLayoutDirection(Qt.RightToLeft)
#     169 # Create and show the GUI
# --> 170 gui = ArabicTextPredictorGUI(model, tokenizer, seq_len)
#     171 gui.show()
#     173 sys.exit(app.exec_())
#
# NameError: name 'model' is not defined

# %%
def predict_next_word(model, tokenizer, text, seq_len):
    # Tokenize and pad the input text
    tokenized_text = tokenizer.texts_to_sequences([text])[0]
    padded_text = pad_sequences([tokenized_text[-seq_len:]], maxlen=seq_len, padding='pre')
    
    # Predict the next word
    predictions = model.predict(padded_text)
    predicted_index = np.argmax(predictions, axis=-1)[0]
    
    # Map index back to word
    for word, index in tokenizer.word_index.items():
        if index == predicted_index:
            return word
    return "<UNK>"

def predict_top_five_words(model, tokenizer, text, seq_len):
    # Tokenize and pad the input text
    tokenized_text = tokenizer.texts_to_sequences([text])[0]
    padded_text = pad_sequences([tokenized_text[-seq_len:]], maxlen=seq_len, padding='pre')

    # Predict the next word probabilities
    predictions = model.predict(padded_text, verbose=0)[0]

    # Get top 5 indices
    top_five_indexes = np.argsort(predictions)[::-1][:5]

    # Map indices back to words
    top_five_words = []
    for idx in top_five_indexes:
        for word, index in tokenizer.word_index.items():
            if index == idx:
                top_five_words.append(word)
                break

    return top_five_words

# %%
test_sentence = "   اذهب "  # Example sentence
next_word = predict_next_word(model, tokenizer, test_sentence, seq_len)
print(f"Next word after '{test_sentence}': {next_word}")
print("Top 5 predictions: ", predict_top_five_words(model, tokenizer, test_sentence, seq_len))

# %%
# from tensorflow.keras.models import model_from_json

# model_json = model.to_json()
# with open("lstm_model2.json", "w") as json_file:
#     json_file.write(model_json)

# %%
# from tensorflow.keras.models import model_from_json

# with open("lstm_model2.json", "r") as json_file:
#     loaded_model_json = json_file.read()

# # Create model from loaded architecture
# loaded_model = model_from_json(loaded_model_json)

# print("Model architecture loaded successfully from JSON file.")

# %%
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Plot Accuracy
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
